# %%
import pandas as pd

# %%
data=pd.read_csv(r'D:\Desktop\Semester 6\Pattern\lab\04_02_2025\Pattern_Rocognition_and_anomaly_detection_lab\Dataset\nyc_taxi.csv')
data['timestamp'] = pd.to_datetime(data['timestamp'])

# %%
data.head()
# Out:
#             timestamp  value
# 0 2014-07-01 00:00:00  10844
# 1 2014-07-01 00:30:00   8127
# 2 2014-07-01 01:00:00   6210
# 3 2014-07-01 01:30:00   4656
# 4 2014-07-01 02:00:00   3820

# %%
# create moving-averages
data['MA60'] = data['value'].rolling(60).mean()
data['MA365'] = data['value'].rolling(365).mean()
data.tail()
# Out:
#                 timestamp  value          MA60         MA365
# 10315 2015-01-31 21:30:00  24670  19638.816667  13308.419178
# 10316 2015-01-31 22:00:00  25721  19807.800000  13361.350685
# 10317 2015-01-31 22:30:00  27309  20017.633333  13415.520548
# 10318 2015-01-31 23:00:00  26591  20168.000000  13460.742466
# 10319 2015-01-31 23:30:00  26288  20255.916667  13501.473973

# %%
# plot 
import plotly.express as px
fig = px.line(data, x="timestamp", y=['value', 'MA60', 'MA365'], title='NYC Taxi Trips', template = 'plotly_dark')
fig.show()

# %%
data.drop(['MA60', 'MA365'], axis=1, inplace=True)
data.head()
# Out:
#                      value  day day_name  day_of_year  week_of_year  hour  \
# timestamp
# 2014-07-01 00:00:00  10844    1  Tuesday          182            27     0
# 2014-07-01 00:30:00   8127    1  Tuesday          182            27     0
# 2014-07-01 01:00:00   6210    1  Tuesday          182            27     1
# 2014-07-01 01:30:00   4656    1  Tuesday          182            27     1
# 2014-07-01 02:00:00   3820    1  Tuesday          182            27     2
#
#                      is_weekday
# timestamp
# 2014-07-01 00:00:00           2
# 2014-07-01 00:30:00           2
# 2014-07-01 01:00:00           2
# 2014-07-01 01:30:00           2
# 2014-07-01 02:00:00           2

# %%
print(data.columns)
# Out:
# Index(['value', 'day', 'day_name', 'day_of_year', 'week_of_year', 'hour',
#        'is_weekday'],
#       dtype='object')

# %%
# set timestamp to index
data.set_index('timestamp', drop=True, inplace=True)
data.head()
# Out:
#                      value  MA60  MA365
# timestamp
# 2014-07-01 00:00:00  10844   NaN    NaN
# 2014-07-01 00:30:00   8127   NaN    NaN
# 2014-07-01 01:00:00   6210   NaN    NaN
# 2014-07-01 01:30:00   4656   NaN    NaN
# 2014-07-01 02:00:00   3820   NaN    NaN

# %%
# resample timeseries to hourly 
data = data.resample('H').sum()
data.head()
# Out:
#                      value  day        day_name  day_of_year  week_of_year  \
# timestamp
# 2014-07-01 00:00:00  18971    2  TuesdayTuesday          364            54
# 2014-07-01 01:00:00  10866    2  TuesdayTuesday          364            54
# 2014-07-01 02:00:00   6693    2  TuesdayTuesday          364            54
# 2014-07-01 03:00:00   4433    2  TuesdayTuesday          364            54
# 2014-07-01 04:00:00   4379    2  TuesdayTuesday          364            54
#
#                      hour  is_weekday
# timestamp
# 2014-07-01 00:00:00     0           4
# 2014-07-01 01:00:00     2           4
# 2014-07-01 02:00:00     4           4
# 2014-07-01 03:00:00     6           4
# 2014-07-01 04:00:00     8           4

# %%
data['day'] = [i.day for i in data.index]
data['day_name'] = [i.day_name() for i in data.index]
data['day_of_year'] = [i.dayofyear for i in data.index]
data['week_of_year'] = [i.weekofyear for i in data.index]
data['hour'] = [i.hour for i in data.index]
data['is_weekday'] = [i.isoweekday() for i in data.index]
data.head()
# Out:
#                      value  day day_name  day_of_year  week_of_year  hour  \
# timestamp
# 2014-07-01 00:00:00  18971    1  Tuesday          182            27     0
# 2014-07-01 01:00:00  10866    1  Tuesday          182            27     1
# 2014-07-01 02:00:00   6693    1  Tuesday          182            27     2
# 2014-07-01 03:00:00   4433    1  Tuesday          182            27     3
# 2014-07-01 04:00:00   4379    1  Tuesday          182            27     4
#
#                      is_weekday
# timestamp
# 2014-07-01 00:00:00           2
# 2014-07-01 01:00:00           2
# 2014-07-01 02:00:00           2
# 2014-07-01 03:00:00           2
# 2014-07-01 04:00:00           2

# %%
from pycaret.anomaly import *
s = setup(data, session_id = 42,
          ordinal_features = {'day_name' : ['Monday', 'Tuesday', 'Wednesday', 'Thursday',
       'Friday','Sunday','Saturday',]},
          numeric_features=['is_weekday'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 from pycaret.anomaly import *
#       2 s = setup(data, session_id = 42,
#       3           ordinal_features = {'day_name' : ['Monday', 'Tuesday', 'Wednesday', 'Thursday',
#       4        'Friday','Sunday','Saturday',]},
#       5           numeric_features=['is_weekday'])
#
# ModuleNotFoundError: No module named 'pycaret'
